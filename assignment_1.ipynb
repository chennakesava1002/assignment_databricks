# %%
# %sql
use catalog demo_catalog

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS demo_catalog.demo_schema;

# %%
data = [
    (101, "Ravi", "Hyderabad", 30),
    (102, "Sita", "Chennai", 25),
    (103, "John", "Bangalore", 35),
    (104, "Priya", "Mumbai", 28)
]

columns = ["customer_id", "customer_name", "city", "age"]

df = spark.createDataFrame(data, columns)

df.show()
df.printSchema()

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("demo_catalog.demo_schema.customers")

# %%
# %sql
DESCRIBE detail demo_catalog.demo_schema.customers;

# %%
# %sql
DROP TABLE IF EXISTS demo_catalog.demo_schema.customers;

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("demo_catalog.demo_schema.customers")

# %%
# %sql
--select * from demo_catalog.demo_schema.customers

DESCRIBE HISTORY demo_catalog.demo_schema.customers

# %%
# %sql
INSERT INTO demo_catalog.demo_schema.customers
(customer_id, customer_name, city, age)
VALUES
(106, 'Kiran', 'Delhi', 29),
(107, 'Meena', 'Kochi', 31),
(108, 'Vijay', 'Mumbai', 27);

# %%
# %sql
DESCRIBE HISTORY demo_catalog.demo_schema.customers

# %%
# %sql
select * from demo_catalog.demo_schema.customers

# %%
# %sql
UPDATE demo_catalog.demo_schema.customers
SET city = 'Hyderabad'
WHERE customer_id = 104;

# %%
# %sql
DESCRIBE HISTORY demo_catalog.demo_schema.customers

# %%
# %sql
SELECT *
FROM demo_catalog.demo_schema.customers VERSION AS OF 0;

--SELECT * FROM demo_catalog.demo_schema.customers TIMESTAMP AS OF '2026-08-24T03:23:59Z';

# %%
# %sql
SELECT *
FROM demo_catalog.demo_schema.customers VERSION AS OF 1

EXCEPT

SELECT *
FROM demo_catalog.demo_schema.customers VERSION AS OF 2;

# %%
# %sql 
--RESTORE TABLE demo_catalog.demo_schema.customers TO VERSION AS OF 0;

SELECT * FROM demo_catalog.demo_schema.customers

# %%
# %sql
DESCRIBE HISTORY demo_catalog.demo_schema.customers
